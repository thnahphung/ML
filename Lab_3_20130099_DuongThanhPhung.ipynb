# %% [markdown]
# <a href="https://colab.research.google.com/github/thnahphung/ML/blob/main/Lab_3_20130099_DuongThanhPhung.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Deadline: 23:59, 04/03/2023**

# %% [markdown]
# # Task 1.
# The main aim of this task is to get familiar with the tasks of preprocessing data using Scikit-learn – a Python-based Machine Learning framework and Linear Regression.

# %% [markdown]
# For given 2 datasets (preprocessing_weather.csv, preprocessing_salary_dummy.csv),
# *   Identify issues with these datasets
# *   Then, apply preprocessing techniques to the datasets

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd '/content/gdrive/MyDrive/ML'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/MyDrive/ML

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# %% [markdown]
# #Task 1.1. Dataset preprocessing_weather.csv

# %% [markdown]
# **Issues**:
#
#
# 1.   List item
# 2.   List item
# 3.   List item
# 4.   List item
# ....

# %% [markdown]
# **Preprocessing dataset**:

# %%
dataSet = pd.read_csv("preprocessing_weather.csv")
imputer = SimpleImputer(missing_values=np.nan,strategy='mean')
x=dataSet.iloc[:,2:4].values
dataSet.iloc[:,2:4] = imputer.fit_transform(x)
print(dataSet)
# Out:
#     id   outlook  temperature   humidity  windy play
# 0    1     sunny    85.000000  85.000000  False   no
# 1    2     sunny    80.000000  90.000000   True   no
# 2    3  overcast    83.000000  86.000000  False  yes
# 3    4     rainy    73.846154  96.000000  False  yes
# 4    5     rainy    68.000000  80.000000  False  yes
# 5    6     rainy    65.000000  70.000000   True   no
# 6    7  overcast    64.000000  65.000000   True  yes
# 7    8     sunny    72.000000  95.000000  False   no
# 8    9     sunny    69.000000  82.538462  False  yes
# 9   10     rainy    75.000000  80.000000  False  yes
# 10  11     sunny    75.000000  70.000000   True  yes
# 11  12  overcast    72.000000  90.000000   True  yes
# 12  13  overcast    81.000000  75.000000  False  yes
# 13  14     rainy    71.000000  91.000000   True   no

# %% [markdown]
# #Task 1.2. Dataset preprocessing_salary_dummy.csv

# %% [markdown]
# **Issues**:
#
#
# 1.   List item
# 2.   List item
# 3.   List item
# 4.   List item
# ....

# %% [markdown]
# **Preprocessing dataset**:

# %%
dataset = pd.read_csv('preprocessing_salary_dummy.csv')
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
X = dataset.iloc[:, 2:4].values
dataset.iloc[:,2:4] = imputer.fit_transform(X)
dataset
# Out:
#    No    Country        Age       Salary  Purchased
# 0   1     France  44.000000  72000.000000        No
# 1   2      Spain  27.000000  48000.000000       Yes
# 2   3    Germany  30.000000  54000.000000        No
# 3   4      Spain  38.000000  61000.000000        No
# 4   5    Germany  40.000000  63777.777778       Yes
# 5   6     France  35.000000  58000.000000       Yes
# 6   7      Spain  38.777778  52000.000000        No
# 7   8     France  48.000000  79000.000000       Yes
# 8   9    Germany  50.000000  83000.000000        No
# 9  10     France  37.000000  67000.000000       Yes

# %% [markdown]
# # **Task 2**. Simple Linear Regression in Scikit-Learn
# ---
# # **Usage:**
# > **Step 1**: build a model
# ![image.png](data:image/png;base64,...)
#
# > **Step 2**: test the model
#
# *   With test set:
# `y_pred = regressor.predict(X_test)`
#
# *   With a single value ("predict" method always expects a 2D array as the format of its inputs)
# `regressor.predict([[12]])`
#
# > **Step 3**:
# *   get w0, w1 , w2, …,
# -- W0: `regressor.intercept_`
# -- w1, w2, …: `regressor.coef_`
# *   R^2 score: sum of squared r(i)
# `r(i) = y(i) - f(x(i))`: residual of ith instance
#
#
# > **Metrics**:
# *   metrics.explained_variance_score(y_test, y_pred)
# *   metrics.mean_absolute_error(y_ test, y_pred)
# *   metrics.mean_squared_error(y_ test, y_pred[, ...])
# *   metrics.mean_squared_log_error(y_ test, y_pred)
# *   metrics.median_absolute_error(y_ test, y_pred)
# *   metrics.r2_score(y_ test, y_pred[, ...])

# %%
from sklearn.model_selection import train_test_split as sp
from sklearn.linear_model import LinearRegression as lr
from sklearn.model_selection import train_test_split as tts
from sklearn import metrics as me
from sklearn.preprocessing import StandardScaler as ss

# %% [markdown]
# # Tasks
# The main aim of these tasks is to get familiar with Linear Regression problems. Apply LinearRegression to the following datasets. Note the error obtained and coefficients
# *   **dataset1.csv** - a synthetic dataset including 5 points (1-dimensional data) with one target
# *   **dataset2.csv** - a synthetic dataset including 1000 points (3-dimensional data) with one target variable. The variables are named x1, x2, x3, y. y is the variable to be regressed. Split the dataset into training set and test set (70% for training set and 30% for test set).

# %% [markdown]
# # Task 2.1. dataset1.csv

# %%
dataset1 = pd.read_csv('dataset1.csv')
x_train = dataset1[['x']]
y_train = dataset1[['y']]
re = lr()
re.fit(x_train,y_train)
print(re.intercept_)
print(re.coef_)
# Out:
# [0.4]
# [[0.8]]

# %%
y_pred = re.predict(x_train)
print(y_pred)
# Out:
# [[1.2]
#  [2. ]
#  [3.6]
#  [2.8]
#  [4.4]]

# %%
print(me.r2_score(y_train,y_pred))
# Out:
# 0.7272727272727273

# %% [markdown]
# # Task 2.2. dataset2.csv

# %%
dataset2 = pd.read_csv('dataset2.csv')
x_train_2, x_test_2, y_train_2, y_test_2 = tts(dataset2.iloc[:,2:5],dataset2[['y']],test_size=0.3)
re.fit(x_train_2,y_train_2)
print(re.intercept_)
print(re.coef_)
# Out:
# [8.8817842e-16]
# [[ 1.14681153e-15 -8.88178420e-16  1.00000000e+00]]

# %%
y_pred_2 = re.predict(x_test_2)
print(y_pred_2)
# Out:
# [[ 1.8967e+01]
#  [ 7.4947e-01]
#  [ 2.8040e+01]
#  [ 1.4074e+01]
#  [ 1.4411e+01]
#  [-6.3582e+00]
#  [ 9.9936e+00]
#  [-7.1737e+00]
#  [-3.1192e+00]
#  [ 8.5321e+00]
#  [-1.0159e+01]
#  [-4.1702e+00]
#  [ 4.0519e+00]
#  [ 9.3442e+00]
#  [ 4.0496e+00]
#  [-3.1307e+00]
#  [-1.7966e+01]
#  [-3.1207e+00]
#  [ 1.3916e+01]
#  [ 1.9713e+00]
#  [ 1.6534e+01]
#  [ 8.1965e+00]
#  [ 1.0922e+01]
#  [-8.9933e-01]
#  [-1.5792e+00]
#  [ 1.0552e+00]
#  [-1.1235e+01]
#  [ 1.3404e+01]
#  [-5.3988e+00]
#  [ 1.9271e+01]
#  [ 1.4409e+01]
#  [-6.6856e+00]
#  [-7.0631e+00]
#  [-1.7672e+01]
#  [ 3.8574e+00]
#  [ 1.6136e+01]
#  [ 2.0344e+01]
#  [-1.7204e+01]
#  [ 5.6347e+00]
#  [ 9.3257e+00]
#  [ 1.3867e+01]
#  [ 9.3255e-01]
#  [ 1.6891e+01]
#  [-1.5683e+01]
#  [-7.3659e-01]
#  [ 1.0536e+01]
#  [-8.4965e-02]
#  [ 1.4267e+01]
#  [ 1.9494e+01]
#  [-1.3890e+00]
#  [ 9.6148e+00]
#  [ 4.5706e+00]
#  [ 1.2967e+01]
#  [ 3.0126e+00]
#  [ 6.6490e+00]
#  [ 1.0031e+00]
#  [ 5.9609e+00]
#  [ 6.6921e+00]
#  [-1.2938e+01]
#  [ 4.5395e+00]
#  [ 3.8810e+00]
#  [-4.4489e+00]
#  [ 1.0518e+01]
#  [ 2.0391e+01]
#  [ 1.4717e+01]
#  [-8.2293e+00]
#  [-1.2108e+00]
#  [ 2.9329e+01]
#  [ 8.3080e+00]
#  [ 8.4678e+00]
#  [ 7.5096e+00]
#  [-6.7037e+00]
#  [ 2.0365e+01]
#  [ 3.5364e+00]
#  [ 1.5353e+01]
#  [ 1.9991e+01]
#  [ 2.3105e+01]
#  [-4.5457e+00]
#  [ 3.3819e+00]
#  [ 1.2992e+01]
#  [-2.4194e+00]
#  [ 1.2348e+01]
#  [-6.3476e+00]
#  [-4.1999e+00]
#  [ 1.5190e+01]
#  [-9.9544e+00]
#  [-4.1029e+00]
#  [ 1.0743e+01]
#  [ 8.6228e+00]
#  [-1.2752e+00]
#  [ 4.6820e+00]
#  [ 4.2171e+00]
#  [ 1.3295e+01]
#  [-7.6277e+00]
#  [ 9.9932e+00]
#  [ 5.5680e+00]
#  [ 1.2219e+01]
#  [ 1.3216e+00]
#  [ 7.0824e+00]
#  [ 2.0746e+01]
#  [ 8.9307e+00]
#  [ 8.2203e+00]
#  [ 7.7864e+00]
#  [ 7.2845e-01]
#  [ 1.0328e+01]
#  [ 9.3879e+00]
#  [-5.3367e+00]
#  [ 2.8769e+00]
#  [-4.4007e+00]
#  [ 7.9460e-01]
#  [ 1.8343e+01]
#  [-5.1563e+00]
#  [-3.4388e+00]
#  [ 2.1442e+01]
#  [ 9.0164e+00]
#  [ 4.7947e+00]
#  [-1.8202e+01]
#  [-1.2782e+01]
#  [-1.4003e+01]
#  [ 2.8773e+00]
#  [ 1.2656e-02]
#  [-1.1274e+01]
#  [ 8.7689e+00]
#  [-9.1467e+00]
#  [ 1.1670e+01]
#  [ 1.2218e+01]
#  [ 2.7823e+00]
#  [-9.6752e-01]
#  [-9.7625e+00]
#  [-6.7680e+00]
#  [-6.9492e+00]
#  [-1.2566e+01]
#  [ 2.4489e+00]
#  [ 3.2350e+00]
#  [ 4.3893e+00]
#  [-6.4355e+00]
#  [ 2.1074e+01]
#  [ 7.6984e+00]
#  [ 1.0537e+01]
#  [ 4.2549e+00]
#  [-1.0721e+01]
#  [ 9.5660e+00]
#  [-1.2023e+01]
#  [-4.3390e-01]
#  [-1.0922e+01]
#  [-1.0778e+01]
#  [ 1.1406e+01]
#  [-5.7217e+00]
#  [-1.7898e+00]
#  [ 7.7110e+00]
#  [-6.8720e+00]
#  [ 6.3958e+00]
#  [-4.8907e+00]
#  [ 1.2660e+01]
#  [ 6.0785e+00]
#  [ 2.9301e+00]
#  [ 1.3904e+00]
#  [-4.8533e+00]
#  [-1.5654e+00]
#  [-6.8056e+00]
#  [ 7.1774e+00]
#  [-8.4608e-01]
#  [-4.5347e+00]
#  [ 9.0270e+00]
#  [-1.4497e+01]
#  [-5.4150e+00]
#  [ 1.2634e+00]
#  [ 4.7816e+00]
#  [-3.6104e+00]
#  [ 6.0196e+00]
#  [ 2.0825e+01]
#  [-1.0518e+01]
#  [-9.0403e+00]
#  [ 9.0638e+00]
#  [-1.7594e+00]
#  [-1.2168e+01]
#  [-1.9586e+00]
#  [-7.8321e+00]
#  [-3.0044e+00]
#  [-5.9170e-01]]

# %%
print(me.r2_score(y_test_2,y_pred_2))
# Out:
# 1.0

# %% [markdown]
# # Task 2.3. Apply LinearRegression to the following dataset:
# *   Red wine quality: https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv . The dataset includes info about the chemical properties of different types of wine and how they relate to overall quality.

# %%
dataset3 = pd.read_csv('Task3_winequality-red.csv',sep=';')
x_train_3, x_test_3, y_train_3, y_test_3 = tts(dataset3.iloc[:,:12],dataset3[['quality']],test_size=0.3)
re.fit(x_train_3,y_train_3)
print(re.intercept_)
print(re.coef_)
# Out:
# [9.68114477e-14]
# [[ 2.82391191e-16  1.01307851e-15 -4.50811263e-16 -3.10081821e-16
#   -1.88824989e-15  7.11236625e-17 -3.46944695e-17 -8.99556190e-14
#   -2.25730892e-16  3.52447021e-16 -2.68123197e-16  1.00000000e+00]]

# %%
y_pred_3 = re.predict(x_test_3)
print(y_pred_3)
# Out:
# [[6.]
#  [6.]
#  [6.]
#  [6.]
#  [6.]
#  [6.]
#  [7.]
#  [6.]
#  [6.]
#  [6.]
#  [6.]
#  [5.]
#  [6.]
#  [6.]
#  [6.]
#  [7.]
#  [5.]
#  [5.]
#  [7.]
#  [6.]
#  [7.]
#  [6.]
#  [7.]
#  [4.]
#  [6.]
#  [5.]
#  [5.]
#  [5.]
#  [6.]
#  [6.]
#  [6.]
#  [5.]
#  [5.]
#  [6.]
#  [5.]
#  [6.]
#  [5.]
#  [5.]
#  [6.]
#  [6.]
#  [6.]
#  [5.]
#  [5.]
#  [6.]
#  [6.]
#  [7.]
#  [5.]
#  [5.]
#  [6.]
#  [7.]
#  [6.]
#  [5.]
#  [5.]
#  [6.]
#  [5.]
#  [6.]
#  [5.]
#  [7.]
#  [7.]
#  [6.]
#  [6.]
#  [5.]
#  [5.]
#  [5.]
#  [7.]
#  [5.]
#  [6.]
#  [6.]
#  [6.]
#  [5.]
#  [6.]
#  [6.]
#  [5.]
#  [6.]
#  [8.]
#  [5.]
#  [6.]
#  [6.]
#  [5.]
#  [5.]
#  [6.]
#  [6.]
#  [5.]
#  [4.]
#  [5.]
#  [5.]
#  [6.]
#  [6.]
#  [5.]
#  [5.]
#  [7.]
#  [5.]
#  [5.]
#  [5.]
#  [6.]
#  [6.]
#  [5.]
#  [5.]
#  [7.]
#  [6.]
#  [6.]
#  [4.]
#  [4.]
#  [6.]
#  [5.]
#  [7.]
#  [5.]
#  [6.]
#  [6.]
#  [5.]
#  [5.]
#  [5.]
#  [5.]
#  [6.]
#  [6.]
#  [6.]
#  [5.]
#  [5.]
#  [6.]
#  [7.]
#  [7.]
#  [6.]
#  [8.]
#  [5.]
#  [5.]
#  [5.]
#  [6.]
#  [5.]
#  [5.]
#  [5.]
#  [6.]
#  [5.]
#  [5.]
#  [5.]
#  [5.]
#  [6.]
#  [8.]
#  [7.]
#  [6.]
#  [4.]
#  [6.]
#  [6.]
#  [6.]
#  [5.]
#  [6.]
#  [5.]
#  [6.]
#  [5.]
#  [7.]
#  [5.]
#  [5.]
#  [5.]
#  [5.]
#  [7.]
#  [5.]
#  [4.]
#  [6.]
#  [5.]
#  [6.]
#  [6.]
#  [5.]
#  [5.]
#  [8.]
#  [6.]
#  [7.]
#  [7.]
#  [5.]
#  [5.]
#  [5.]
#  [6.]
#  [6.]
#  [6.]
#  [6.]
#  [6.]
#  [6.]
#  [5.]
#  [6.]
#  [5.]
#  [8.]
#  [6.]
#  [6.]
#  [6.]
#  [7.]
#  [5.]
#  [6.]
#  [4.]
#  [5.]
#  [7.]
#  [6.]
#  [5.]
#  [5.]
#  [5.]
#  [3.]
#  [5.]
#  [5.]
#  [6.]
#  [6.]
#  [5.]
#  [6.]
#  [6.]
#  [4.]
#  [7.]
#  [5.]
#  [5.]
#  [5.]
#  [5.]
#  [5.]
#  [8.]
#  [6.]
#  [6.]
#  [5.]
#  [5.]
#  [5.]
#  [3.]
#  [6.]
#  [5.]
#  [5.]
#  [6.]
#  [6.]
#  [5.]
#  [5.]
#  [6.]
#  [6.]
#  [6.]
#  [5.]
#  [5.]
#  [6.]
#  [6.]
#  [5.]
#  [5.]
#  [6.]
#  [6.]
#  [4.]
#  [5.]
#  [5.]
#  [6.]
#  [6.]
#  [5.]
#  [7.]
#  [5.]
#  [7.]
#  [7.]
#  [5.]
#  [6.]
#  [5.]
#  [5.]
#  [6.]
#  [7.]
#  [6.]
#  [5.]
#  [6.]
#  [7.]
#  [5.]
#  [5.]
#  [3.]
#  [5.]
#  [5.]
#  [5.]
#  [5.]
#  [5.]
#  [6.]
#  [5.]
#  [5.]
#  [6.]
#  [6.]
#  [5.]
#  [6.]
#  [6.]
#  [7.]
#  [5.]
#  [6.]
#  [5.]
#  [6.]
#  [6.]
#  [4.]
#  [6.]
#  [7.]
#  [5.]
#  [7.]
#  [5.]
#  [5.]
#  [6.]
#  [4.]
#  [6.]
#  [4.]
#  [7.]
#  [5.]
#  [7.]
#  [7.]
#  [5.]
#  [6.]
#  [6.]
#  [8.]
#  [5.]
#  [5.]
#  [5.]
#  [6.]
#  [5.]
#  [6.]
#  [5.]
#  [5.]
#  [6.]
#  [5.]
#  [6.]
#  [6.]
#  [7.]
#  [5.]
#  [6.]
#  [5.]
#  [5.]
#  [5.]
#  [5.]
#  [5.]
#  [6.]
#  [6.]
#  [6.]
#  [5.]
#  [6.]
#  [5.]
#  [6.]
#  [6.]
#  [5.]
#  [7.]
#  [5.]
#  [5.]
#  [7.]
#  [6.]
#  [7.]
#  [5.]
#  [4.]
#  [6.]
#  [6.]
#  [5.]
#  [5.]
#  [5.]
#  [6.]
#  [7.]
#  [5.]
#  [5.]
#  [6.]
#  [5.]
#  [5.]
#  [6.]
#  [5.]
#  [7.]
#  [5.]
#  [5.]
#  [5.]
#  [5.]
#  [7.]
#  [6.]
#  [6.]
#  [7.]
#  [5.]
#  [6.]
#  [6.]
#  [6.]
#  [5.]
#  [5.]
#  [7.]
#  [5.]
#  [6.]
#  [6.]
#  [6.]
#  [6.]
#  [6.]
#  [7.]
#  [5.]
#  [5.]
#  [6.]
#  [4.]
#  [5.]
#  [6.]
#  [5.]
#  [5.]
#  [6.]
#  [7.]
#  [5.]
#  [5.]
#  [6.]
#  [6.]
#  [6.]
#  [5.]
#  [6.]
#  [6.]
#  [3.]
#  [7.]
#  [6.]
#  [6.]
#  [5.]
#  [5.]
#  [6.]
#  [5.]
#  [7.]
#  [6.]
#  [5.]
#  [5.]
#  [5.]
#  [5.]
#  [5.]
#  [6.]
#  [6.]
#  [5.]
#  [7.]
#  [6.]
#  [5.]
#  [6.]
#  [7.]
#  [5.]
#  [5.]
#  [5.]
#  [7.]
#  [5.]
#  [6.]
#  [5.]
#  [6.]
#  [5.]
#  [6.]
#  [6.]
#  [5.]
#  [6.]
#  [7.]
#  [5.]
#  [5.]
#  [5.]
#  [5.]
#  [6.]
#  [6.]
#  [6.]
#  [7.]
#  [6.]
#  [7.]
#  [5.]
#  [5.]
#  [7.]
#  [5.]
#  [6.]
#  [5.]
#  [6.]
#  [5.]
#  [6.]
#  [4.]
#  [6.]
#  [6.]
#  [5.]
#  [6.]
#  [5.]
#  [7.]
#  [5.]
#  [6.]
#  [7.]
#  [5.]
#  [5.]
#  [5.]
#  [4.]
#  [6.]
#  [5.]
#  [6.]
#  [5.]
#  [6.]
#  [6.]
#  [5.]
#  [6.]
#  [5.]
#  [6.]
#  [6.]
#  [6.]
#  [6.]
#  [5.]
#  [4.]
#  [6.]
#  [6.]
#  [6.]
#  [6.]
#  [5.]
#  [6.]
#  [6.]
#  [5.]
#  [5.]
#  [7.]]

# %%
print(me.r2_score(y_test_3,y_pred_3))
# Out:
# 1.0

# %% [markdown]
# # Task 2.4. Apply LinearRegression to the following dataset:
# *   Energy efficiency: https://archive.ics.uci.edu/ml/datasets/Energy+efficiency.

# %%
dataset4 = pd.read_excel('Task4_ENB2012_data.xlsx')
x_train_4, x_test_4, y_train_4, y_test_4 = tts(dataset4.iloc[:,:9],dataset4.iloc[:,9:],test_size=0.3)
re.fit(x_train_4,y_train_4)
print(re.intercept_)
print(re.coef_)
# Out:
# [24.40759582]
# [[-1.57804142e+01  1.86840463e+11 -1.86840463e+11 -3.73680926e+11
#    8.77740383e-01  1.52027274e-01 -2.54776288e+00 -1.47953063e-01
#    8.55426788e-01]]

# %%
y_pred_4 = re.predict(x_test_4)
print(y_pred_4)
# Out:
# [[31.76313503]
#  [30.89214341]
#  [33.25428818]
#  [14.58487969]
#  [16.19020004]
#  [15.28893216]
#  [17.49011491]
#  [15.47730117]
#  [20.20608431]
#  [32.76408628]
#  [13.94662773]
#  [14.58147605]
#  [15.68077107]
#  [28.00478669]
#  [34.74373237]
#  [41.90813137]
#  [34.06727135]
#  [15.11208777]
#  [38.03932217]
#  [14.88359006]
#  [31.14917729]
#  [18.56071214]
#  [40.07353549]
#  [40.4067891 ]
#  [16.72636335]
#  [17.8761236 ]
#  [38.34496342]
#  [15.22560204]
#  [17.83742647]
#  [29.72444657]
#  [16.85976093]
#  [14.37364311]
#  [39.03902105]
#  [14.28239216]
#  [14.47900896]
#  [20.40128877]
#  [19.7509173 ]
#  [19.23692153]
#  [16.74366954]
#  [15.08069337]
#  [32.27036734]
#  [20.16489915]
#  [34.03923881]
#  [34.19068513]
#  [41.22313698]
#  [26.95572813]
#  [18.68920128]
#  [17.21505147]
#  [18.78745134]
#  [14.79468549]
#  [17.57166321]
#  [14.91585758]
#  [14.66932752]
#  [14.62214812]
#  [18.7982821 ]
#  [41.27038837]
#  [16.41843225]
#  [29.90466715]
#  [27.10015896]
#  [16.89939826]
#  [16.26852964]
#  [39.95806807]
#  [15.1818905 ]
#  [33.31087083]
#  [39.24572105]
#  [15.1072943 ]
#  [37.0424398 ]
#  [28.60115684]
#  [32.36879914]
#  [14.1659943 ]
#  [31.18804953]
#  [16.31672123]
#  [16.67971546]
#  [34.39845018]
#  [40.83079112]
#  [41.27699309]
#  [17.67635926]
#  [16.45480138]
#  [17.21962114]
#  [33.82792697]
#  [22.50312166]
#  [19.93877735]
#  [32.31297914]
#  [15.61175596]
#  [27.18261915]
#  [16.58049119]
#  [19.42975422]
#  [33.97566651]
#  [14.95422086]
#  [36.8478163 ]
#  [28.52838785]
#  [40.7275704 ]
#  [15.78185118]
#  [29.14275144]
#  [17.03879705]
#  [17.83140271]
#  [16.98155573]
#  [26.56767461]
#  [15.08936466]
#  [42.63620688]
#  [15.28406957]
#  [36.35556786]
#  [40.7063762 ]
#  [13.51298019]
#  [25.03202638]
#  [32.10474035]
#  [42.64999728]
#  [32.98796802]
#  [40.31346083]
#  [35.59831223]
#  [33.79913835]
#  [14.76952022]
#  [26.58088405]
#  [30.31299723]
#  [17.45273844]
#  [18.0556834 ]
#  [28.02791899]
#  [14.76168026]
#  [16.30469626]
#  [37.8531457 ]
#  [18.12029827]
#  [33.41079551]
#  [33.61813014]
#  [14.16458195]
#  [17.65965657]
#  [34.36268941]
#  [31.44239336]
#  [37.84062446]
#  [37.38218724]
#  [16.85586183]
#  [15.73984492]
#  [39.52433092]
#  [30.00324416]
#  [36.84309325]
#  [14.58011647]
#  [29.69455943]
#  [16.99060546]
#  [40.23743516]
#  [14.825501  ]
#  [30.00635563]
#  [29.7823769 ]
#  [33.76339192]
#  [16.3060423 ]
#  [28.30734547]
#  [16.37644439]
#  [15.46818926]
#  [38.23004657]
#  [31.28140597]
#  [35.05867251]
#  [32.08243409]
#  [13.72488734]
#  [15.51163526]
#  [30.83252417]
#  [15.50095633]
#  [15.29271754]
#  [39.93160618]
#  [40.32492739]
#  [15.71734353]
#  [29.71452371]
#  [13.80848047]
#  [41.96548073]
#  [19.89405646]
#  [33.47798961]
#  [33.85553932]
#  [16.37178921]
#  [20.19092533]
#  [15.79683505]
#  [14.28597577]
#  [37.4107864 ]
#  [36.11759206]
#  [15.87187391]
#  [11.56633105]
#  [27.37741777]
#  [33.6895931 ]
#  [14.11576354]
#  [39.30909418]
#  [15.27339064]
#  [34.25692673]
#  [19.17525084]
#  [15.50045678]
#  [17.23160236]
#  [36.58147208]
#  [17.27755147]
#  [33.80479467]
#  [15.09847249]
#  [10.92930731]
#  [37.47260321]
#  [26.52897748]
#  [31.79694625]
#  [20.7755519 ]
#  [15.59715053]
#  [14.92355715]
#  [37.14020511]
#  [14.87734049]
#  [17.33492824]
#  [39.95498067]
#  [17.96525482]
#  [27.87606683]
#  [16.2242146 ]
#  [29.16800839]
#  [43.15315538]
#  [42.66108206]
#  [14.08629125]
#  [15.24982918]
#  [32.38550183]
#  [29.56657065]
#  [30.29920887]
#  [14.43325826]
#  [17.09880828]
#  [17.1033321 ]
#  [27.64725524]
#  [14.99597877]
#  [28.63577976]
#  [15.77648371]
#  [14.09973143]
#  [27.46528686]
#  [30.20586596]
#  [11.95397873]
#  [34.62345954]
#  [30.36685334]
#  [15.23126656]
#  [18.86924675]
#  [37.5083766 ]
#  [16.60682866]
#  [20.0289752 ]
#  [28.6250153 ]
#  [20.31692643]
#  [29.69903949]
#  [11.76840496]
#  [17.4143903 ]
#  [29.77439867]]

# %%
print(me.r2_score(y_test_4,y_pred_4))
# Out:
# 0.959846830672012

# %% [markdown]
# # Finally,
# Save a copy in your Github. Remember renaming the notebook.
